# %% [markdown]
# Arrata de suitzìdius in Sardìnnia e in Europa
# =============================================

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

nuts = gpd.read_file('nuts/NUTS_RG_20M_2021_3035.shp')
nuts.head()

# %%
nuts_regions = nuts.loc[nuts['LEVL_CODE']==1]
nuts_regions.plot(figsize=(15,12))
plt.gca().set_ylim([1e6, 7e6])
plt.gca().set_xlim([0.2*1e7, 0.8*1e7])
# Out:
# (1000000.0, 7000000.0)
